# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
driver = webdriver.Chrome('./chromedriver.exe')
driver.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cnt&date=20210721')

nmovie = []

for n in range(2, 56):
    driver.implicitly_wait(5)

    try:
        driver.find_element_by_xpath('//*[@id="old_content"]/table/tbody/tr[%s]/td[2]/div/a' %n).click()
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        datas = soup.select('dl.info_spec')
        data = datas[0]
        outlines = []
        nations = []
        directors = []
        actors = []      

        movie_genre = data.select('dd > p > span > a[href*="genre"]')
        movie_nation = data.select('dd > p > span > a[href*="nation"]')
        movie_director = data.select('dd:nth-child(4) > p > a')
        movie_actor = data.select('dd:nth-child(6) > p > a')

        try :  
            names = soup.select('div.wide_info_area > div.mv_info > h3 > a')
            title = names[0].text.strip()
            href = names[0]['href']

            for i in range(1,len(movie_genre)+1):
                outline = data.select('span:nth-child(1) > a:nth-child(%s)' %i)
                outlines.append(outline[0].text.strip())
        except:
            pass


        try:
            for n in range(1,len(movie_nation)+1):
                nation = data.select('span:nth-child(2) > a:nth-child(%s)' %n)
                nations.append(nation[0].text.strip())
        except:
            pass

        try:
            for z in range(1,len(movie_director)+1):
                director = data.select('dd:nth-child(4) > p > a:nth-child(%s)' %z)
                directors.append(director[0].text.strip())        
        except:
            pass

        try: 
             for s in range(1,len(movie_actor)+1):
                actor = data.select('dd:nth-child(6) > p > a:nth-child(%s)' %s)
                actors.append(actor[0].text.strip())        
        except:
            pass


        movie_data = [title, href, outlines, nations, directors, actors]
        nmovie.append(movie_data)
#                 print('----------')    

        driver.back()

    except:
        pass        

print(nmovie)
# Out:
# [['랑종', './basic.naver?code=204496', ['공포', '스릴러', '드라마'], ['한국', '태국'], ['반종 피산다나쿤'], ['나릴야 군몽콘켓', '싸와니 우툼마', '씨라니 얀키띠칸']], ['블랙 위도우', './basic.naver?code=184318', ['액션', '모험', 'SF'], ['미국'], ['케이트 쇼트랜드'], ['스칼릿 조핸슨', '플로렌스 퓨', '레이첼 와이즈']], ['이스케이프 룸 2: 노 웨이 아웃', './basic.naver?code=191548', ['액션', '공포', '스릴러'], ['미국'], ['애덤 로비텔'], ['테일러 러셀', '로건 밀러']], ['발신제한', './basic.naver?code=194205', ['드라마', '스릴러'], ['한국'], ['김창주'], ['조우진', '이재인', '진경']], ['스페이스 잼: 새로운 시대', './basic.naver?code=203678', ['애니메이션', '모험', '코미디'], ['미국'], ['말콤 D. 리'], ['르브론 제임스', '돈 치들', '젠데이아 콜먼']], ['크루엘라', './basic.naver?code=187322', ['드라마', '범죄', '코미디'], ['미국'], ['크레이그 질레스피'], ['엠마 스톤']], ['오필리아', './basic.naver?code=168074', ['드라마', '멜로/로맨스'], ['미국'], ['클레어 맥카시'], ['데이지 리들리', '조지 맥케이', '나오미 왓츠']], ['보스 베이비 2', './basic.naver?code=191597', ['애니메이션', '코미디', '모험'], ['미국'], ['톰 맥그라스'], ['알렉 볼드윈', '에이미 세다리스']], ['꽃다발 같은 사랑을 했다', './basic.naver?code=200896', ['멜로/로맨스'], ['일본'], ['도이 노부히로'], ['아리무라 카스미', '스다 마사키', '키요하라 카야']], ['킬러의 보디가드 2', './basic.naver?code=204624', ['액션', '코미디', '범죄'], ['미국', '영국'], ['패트릭 휴즈'], ['라이언 레이놀즈', '사무엘 L. 잭슨', '셀마 헤이엑']], ['괴기맨숀', './basic.naver?code=205629', ['공포'], ['한국'], ['조바른'], ['성준', '김홍파', '김보라']], ['아이스 로드', './basic.naver?code=205966', ['스릴러'], ['미국'], ['조나단 헨슬레이'], ['리암 니슨', '로렌스 피시번', '홀트 맥칼라니']], ['루카', './basic.naver?code=202903', ['애니메이션', '모험', '코미디'], ['미국'], ['엔리코 카사로사'], ['제이콥 트렘블레이', '잭 딜런 그레이저', '엠마 버만']], ['모가디슈', './basic.naver?code=192150', ['액션', '드라마'], ['한국'], ['류승완'], ['김윤석', '조인성', '허준호']], ['콰이어트 플레이스 2', './basic.naver?code=189368', ['스릴러'], ['미국'], ['존 크래신스키'], ['에밀리 블런트', '킬리언 머피', '밀리센트 시몬스']], ['방법: 재차의', './basic.naver?code=200785', ['미스터리', '스릴러'], ['한국'], ['김용완'], ['엄지원', '정지소', '정문성']], ['체르노빌 1986', './basic.naver?code=204782', ['액션', '스릴러'], ['러시아 연방'], ['다닐라 코즐로브스키'], ['다닐라 코즐로브스키', '오크사나 아킨쉬나', '필리프 아브데예프']], ['나만 보이니', './basic.naver?code=205614', ['공포', '코미디'], ['한국'], ['임용재'], ['정진운', '솔빈']], ['타이즈', './basic.naver?code=202659', ['SF', '스릴러'], ['독일', '스위스'], ['팀 펠바움'], ['노라 아르네제더', '이아인 글렌', '사라-소피에 바우스니나']], ['미드나이트', './basic.naver?code=189120', ['스릴러'], ['한국'], ['권오승'], ['진기주', '위하준', '박훈']], ['싱크홀', './basic.naver?code=188472', ['드라마'], ['한국'], ['김지훈'], ['차승원', '김성균', '이광수']], ['피닉스', './basic.naver?code=129687', ['드라마'], ['독일', '폴란드'], ['크리스티안 펫졸드'], ['니나 호스', '로날드 제르필드', '니나 쿤젠도르프']], ['올드', './basic.naver?code=200065', ['공포', '스릴러'], ['미국'], ['M. 나이트 샤말란'], ['가엘 가르시아 베르날', '빅키 크리엡스', '토마신 맥켄지']], ['여고괴담 여섯번째 이야기 : 모교', './basic.naver?code=187849', ['미스터리', '공포'], ['한국'], ['이미영'], ['김서형', '김현수', '최리']]]

# %%
import pandas as pd

# %%
pd_data=pd.DataFrame(nmovie, columns=['Title','Code','Genre','Nation','Director','Actor'])
pd_data
# Out:
#                  Title                       Code             Genre  \
# 0                   랑종  ./basic.naver?code=204496    [공포, 스릴러, 드라마]
# 1               블랙 위도우  ./basic.naver?code=184318      [액션, 모험, SF]
# 2   이스케이프 룸 2: 노 웨이 아웃  ./basic.naver?code=191548     [액션, 공포, 스릴러]
# 3                 발신제한  ./basic.naver?code=194205        [드라마, 스릴러]
# 4       스페이스 잼: 새로운 시대  ./basic.naver?code=203678  [애니메이션, 모험, 코미디]
# 5                 크루엘라  ./basic.naver?code=187322    [드라마, 범죄, 코미디]
# 6                 오필리아  ./basic.naver?code=168074     [드라마, 멜로/로맨스]
# 7             보스 베이비 2  ./basic.naver?code=191597  [애니메이션, 코미디, 모험]
# 8        꽃다발 같은 사랑을 했다  ./basic.naver?code=200896          [멜로/로맨스]
# 9           킬러의 보디가드 2  ./basic.naver?code=204624     [액션, 코미디, 범죄]
# 10                괴기맨숀  ./basic.naver?code=205629              [공포]
# 11              아이스 로드  ./basic.naver?code=205966             [스릴러]
# 12                  루카  ./basic.naver?code=202903  [애니메이션, 모험, 코미디]
# 13                모가디슈  ./basic.naver?code=192150         [액션, 드라마]
# 14         콰이어트 플레이스 2  ./basic.naver?code=189368             [스릴러]
# 15             방법: 재차의  ./basic.naver?code=200785       [미스터리, 스릴러]
# 16           체르노빌 1986  ./basic.naver?code=204782         [액션, 스릴러]
# 17              나만 보이니  ./basic.naver?code=205614         [공포, 코미디]
# 18                 타이즈  ./basic.naver?code=202659         [SF, 스릴러]
# 19               미드나이트  ./basic.naver?code=189120             [스릴러]
# 20                 싱크홀  ./basic.naver?code=188472             [드라마]
# 21                 피닉스  ./basic.naver?code=129687             [드라마]
# 22                  올드  ./basic.naver?code=200065         [공포, 스릴러]
# 23  여고괴담 여섯번째 이야기 : 모교  ./basic.naver?code=187849        [미스터리, 공포]
#
#        Nation      Director                               Actor
# 0    [한국, 태국]    [반종 피산다나쿤]       [나릴야 군몽콘켓, 싸와니 우툼마, 씨라니 얀키띠칸]
# 1        [미국]    [케이트 쇼트랜드]          [스칼릿 조핸슨, 플로렌스 퓨, 레이첼 와이즈]
# 2        [미국]      [애덤 로비텔]                     [테일러 러셀, 로건 밀러]
# 3        [한국]         [김창주]                      [조우진, 이재인, 진경]
# 4        [미국]     [말콤 D. 리]            [르브론 제임스, 돈 치들, 젠데이아 콜먼]
# 5        [미국]   [크레이그 질레스피]                             [엠마 스톤]
# 6        [미국]     [클레어 맥카시]           [데이지 리들리, 조지 맥케이, 나오미 왓츠]
# 7        [미국]      [톰 맥그라스]                  [알렉 볼드윈, 에이미 세다리스]
# 8        [일본]     [도이 노부히로]         [아리무라 카스미, 스다 마사키, 키요하라 카야]
# 9    [미국, 영국]      [패트릭 휴즈]       [라이언 레이놀즈, 사무엘 L. 잭슨, 셀마 헤이엑]
# 10       [한국]         [조바른]                      [성준, 김홍파, 김보라]
# 11       [미국]    [조나단 헨슬레이]           [리암 니슨, 로렌스 피시번, 홀트 맥칼라니]
# 12       [미국]    [엔리코 카사로사]       [제이콥 트렘블레이, 잭 딜런 그레이저, 엠마 버만]
# 13       [한국]         [류승완]                     [김윤석, 조인성, 허준호]
# 14       [미국]     [존 크래신스키]         [에밀리 블런트, 킬리언 머피, 밀리센트 시몬스]
# 15       [한국]         [김용완]                     [엄지원, 정지소, 정문성]
# 16   [러시아 연방]  [다닐라 코즐로브스키]  [다닐라 코즐로브스키, 오크사나 아킨쉬나, 필리프 아브데예프]
# 17       [한국]         [임용재]                           [정진운, 솔빈]
# 18  [독일, 스위스]       [팀 펠바움]    [노라 아르네제더, 이아인 글렌, 사라-소피에 바우스니나]
# 19       [한국]         [권오승]                      [진기주, 위하준, 박훈]
# 20       [한국]         [김지훈]                     [차승원, 김성균, 이광수]
# 21  [독일, 폴란드]   [크리스티안 펫졸드]         [니나 호스, 로날드 제르필드, 니나 쿤젠도르프]
# 22       [미국]  [M. 나이트 샤말란]     [가엘 가르시아 베르날, 빅키 크리엡스, 토마신 맥켄지]
# 23       [한국]         [이미영]                      [김서형, 김현수, 최리]

# %%
pd_data['Code'] = pd_data['Code'].str[-6:]
pd_data
# Out:
#                  Title    Code             Genre     Nation      Director  \
# 0                   랑종  204496    [공포, 스릴러, 드라마]   [한국, 태국]    [반종 피산다나쿤]
# 1               블랙 위도우  184318      [액션, 모험, SF]       [미국]    [케이트 쇼트랜드]
# 2   이스케이프 룸 2: 노 웨이 아웃  191548     [액션, 공포, 스릴러]       [미국]      [애덤 로비텔]
# 3                 발신제한  194205        [드라마, 스릴러]       [한국]         [김창주]
# 4       스페이스 잼: 새로운 시대  203678  [애니메이션, 모험, 코미디]       [미국]     [말콤 D. 리]
# 5                 크루엘라  187322    [드라마, 범죄, 코미디]       [미국]   [크레이그 질레스피]
# 6                 오필리아  168074     [드라마, 멜로/로맨스]       [미국]     [클레어 맥카시]
# 7             보스 베이비 2  191597  [애니메이션, 코미디, 모험]       [미국]      [톰 맥그라스]
# 8        꽃다발 같은 사랑을 했다  200896          [멜로/로맨스]       [일본]     [도이 노부히로]
# 9           킬러의 보디가드 2  204624     [액션, 코미디, 범죄]   [미국, 영국]      [패트릭 휴즈]
# 10                괴기맨숀  205629              [공포]       [한국]         [조바른]
# 11              아이스 로드  205966             [스릴러]       [미국]    [조나단 헨슬레이]
# 12                  루카  202903  [애니메이션, 모험, 코미디]       [미국]    [엔리코 카사로사]
# 13                모가디슈  192150         [액션, 드라마]       [한국]         [류승완]
# 14         콰이어트 플레이스 2  189368             [스릴러]       [미국]     [존 크래신스키]
# 15             방법: 재차의  200785       [미스터리, 스릴러]       [한국]         [김용완]
# 16           체르노빌 1986  204782         [액션, 스릴러]   [러시아 연방]  [다닐라 코즐로브스키]
# 17              나만 보이니  205614         [공포, 코미디]       [한국]         [임용재]
# 18                 타이즈  202659         [SF, 스릴러]  [독일, 스위스]       [팀 펠바움]
# 19               미드나이트  189120             [스릴러]       [한국]         [권오승]
# 20                 싱크홀  188472             [드라마]       [한국]         [김지훈]
# 21                 피닉스  129687             [드라마]  [독일, 폴란드]   [크리스티안 펫졸드]
# 22                  올드  200065         [공포, 스릴러]       [미국]  [M. 나이트 샤말란]
# 23  여고괴담 여섯번째 이야기 : 모교  187849        [미스터리, 공포]       [한국]         [이미영]
#
#                                  Actor
# 0        [나릴야 군몽콘켓, 싸와니 우툼마, 씨라니 얀키띠칸]
# 1           [스칼릿 조핸슨, 플로렌스 퓨, 레이첼 와이즈]
# 2                      [테일러 러셀, 로건 밀러]
# 3                       [조우진, 이재인, 진경]
# 4             [르브론 제임스, 돈 치들, 젠데이아 콜먼]
# 5                              [엠마 스톤]
# 6            [데이지 리들리, 조지 맥케이, 나오미 왓츠]
# 7                   [알렉 볼드윈, 에이미 세다리스]
# 8          [아리무라 카스미, 스다 마사키, 키요하라 카야]
# 9        [라이언 레이놀즈, 사무엘 L. 잭슨, 셀마 헤이엑]
# 10                      [성준, 김홍파, 김보라]
# 11           [리암 니슨, 로렌스 피시번, 홀트 맥칼라니]
# 12       [제이콥 트렘블레이, 잭 딜런 그레이저, 엠마 버만]
# 13                     [김윤석, 조인성, 허준호]
# 14         [에밀리 블런트, 킬리언 머피, 밀리센트 시몬스]
# 15                     [엄지원, 정지소, 정문성]
# 16  [다닐라 코즐로브스키, 오크사나 아킨쉬나, 필리프 아브데예프]
# 17                           [정진운, 솔빈]
# 18    [노라 아르네제더, 이아인 글렌, 사라-소피에 바우스니나]
# 19                      [진기주, 위하준, 박훈]
# 20                     [차승원, 김성균, 이광수]
# 21         [니나 호스, 로날드 제르필드, 니나 쿤젠도르프]
# 22     [가엘 가르시아 베르날, 빅키 크리엡스, 토마신 맥켄지]
# 23                      [김서형, 김현수, 최리]

# %%
pd_data['Code'] = pd_data['Code'].str.replace(pat=r'[^\w]', repl=r'', regex=True)
pd_data
# Out:
#                  Title    Code             Genre     Nation      Director  \
# 0                   랑종  204496    [공포, 스릴러, 드라마]   [한국, 태국]    [반종 피산다나쿤]
# 1               블랙 위도우  184318      [액션, 모험, SF]       [미국]    [케이트 쇼트랜드]
# 2   이스케이프 룸 2: 노 웨이 아웃  191548     [액션, 공포, 스릴러]       [미국]      [애덤 로비텔]
# 3                 발신제한  194205        [드라마, 스릴러]       [한국]         [김창주]
# 4       스페이스 잼: 새로운 시대  203678  [애니메이션, 모험, 코미디]       [미국]     [말콤 D. 리]
# 5                 크루엘라  187322    [드라마, 범죄, 코미디]       [미국]   [크레이그 질레스피]
# 6                 오필리아  168074     [드라마, 멜로/로맨스]       [미국]     [클레어 맥카시]
# 7             보스 베이비 2  191597  [애니메이션, 코미디, 모험]       [미국]      [톰 맥그라스]
# 8        꽃다발 같은 사랑을 했다  200896          [멜로/로맨스]       [일본]     [도이 노부히로]
# 9           킬러의 보디가드 2  204624     [액션, 코미디, 범죄]   [미국, 영국]      [패트릭 휴즈]
# 10                괴기맨숀  205629              [공포]       [한국]         [조바른]
# 11              아이스 로드  205966             [스릴러]       [미국]    [조나단 헨슬레이]
# 12                  루카  202903  [애니메이션, 모험, 코미디]       [미국]    [엔리코 카사로사]
# 13                모가디슈  192150         [액션, 드라마]       [한국]         [류승완]
# 14         콰이어트 플레이스 2  189368             [스릴러]       [미국]     [존 크래신스키]
# 15             방법: 재차의  200785       [미스터리, 스릴러]       [한국]         [김용완]
# 16           체르노빌 1986  204782         [액션, 스릴러]   [러시아 연방]  [다닐라 코즐로브스키]
# 17              나만 보이니  205614         [공포, 코미디]       [한국]         [임용재]
# 18                 타이즈  202659         [SF, 스릴러]  [독일, 스위스]       [팀 펠바움]
# 19               미드나이트  189120             [스릴러]       [한국]         [권오승]
# 20                 싱크홀  188472             [드라마]       [한국]         [김지훈]
# 21                 피닉스  129687             [드라마]  [독일, 폴란드]   [크리스티안 펫졸드]
# 22                  올드  200065         [공포, 스릴러]       [미국]  [M. 나이트 샤말란]
# 23  여고괴담 여섯번째 이야기 : 모교  187849        [미스터리, 공포]       [한국]         [이미영]
#
#                                  Actor
# 0        [나릴야 군몽콘켓, 싸와니 우툼마, 씨라니 얀키띠칸]
# 1           [스칼릿 조핸슨, 플로렌스 퓨, 레이첼 와이즈]
# 2                      [테일러 러셀, 로건 밀러]
# 3                       [조우진, 이재인, 진경]
# 4             [르브론 제임스, 돈 치들, 젠데이아 콜먼]
# 5                              [엠마 스톤]
# 6            [데이지 리들리, 조지 맥케이, 나오미 왓츠]
# 7                   [알렉 볼드윈, 에이미 세다리스]
# 8          [아리무라 카스미, 스다 마사키, 키요하라 카야]
# 9        [라이언 레이놀즈, 사무엘 L. 잭슨, 셀마 헤이엑]
# 10                      [성준, 김홍파, 김보라]
# 11           [리암 니슨, 로렌스 피시번, 홀트 맥칼라니]
# 12       [제이콥 트렘블레이, 잭 딜런 그레이저, 엠마 버만]
# 13                     [김윤석, 조인성, 허준호]
# 14         [에밀리 블런트, 킬리언 머피, 밀리센트 시몬스]
# 15                     [엄지원, 정지소, 정문성]
# 16  [다닐라 코즐로브스키, 오크사나 아킨쉬나, 필리프 아브데예프]
# 17                           [정진운, 솔빈]
# 18    [노라 아르네제더, 이아인 글렌, 사라-소피에 바우스니나]
# 19                      [진기주, 위하준, 박훈]
# 20                     [차승원, 김성균, 이광수]
# 21         [니나 호스, 로날드 제르필드, 니나 쿤젠도르프]
# 22     [가엘 가르시아 베르날, 빅키 크리엡스, 토마신 맥켄지]
# 23                      [김서형, 김현수, 최리]

# %%
pd_data.to_excel('./saves/naver_movie_data_demand.xls', index=False)
