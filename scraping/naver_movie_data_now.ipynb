# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
driver = webdriver.Chrome('./chromedriver.exe')
driver.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20210721')

nmovie = []

for n in range(2, 36):
    driver.implicitly_wait(5)

    try:
        driver.find_element_by_xpath('//*[@id="old_content"]/table/tbody/tr[%s]/td[2]/div/a' %n).click()
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        datas = soup.select('dl.info_spec')
        data = datas[0]
        outlines = []
        nations = []
        directors = []
        actors = []      

        movie_genre = data.select('dd > p > span > a[href*="genre"]')
        movie_nation = data.select('dd > p > span > a[href*="nation"]')
        movie_director = data.select('dd:nth-child(4) > p > a')
        movie_actor = data.select('dd:nth-child(6) > p > a')

        try :  
            names = soup.select('div.wide_info_area > div.mv_info > h3 > a')
            title = names[0].text.strip()
            href = names[0]['href']

            for i in range(1,len(movie_genre)+1):
                outline = data.select('span:nth-child(1) > a:nth-child(%s)' %i)
                outlines.append(outline[0].text.strip())
        except:
            pass


        try:
            for n in range(1,len(movie_nation)+1):
                nation = data.select('span:nth-child(2) > a:nth-child(%s)' %n)
                nations.append(nation[0].text.strip())
        except:
            pass

        try:
            for z in range(1,len(movie_director)+1):
                director = data.select('dd:nth-child(4) > p > a:nth-child(%s)' %z)
                directors.append(director[0].text.strip())        
        except:
            pass

        try: 
             for s in range(1,len(movie_actor)+1):
                actor = data.select('dd:nth-child(6) > p > a:nth-child(%s)' %s)
                actors.append(actor[0].text.strip())        
        except:
            pass


        movie_data = [title, href, outlines, nations, directors, actors]
        nmovie.append(movie_data)
#                 print('----------')    

        driver.back()

    except:
        pass        

print(nmovie)
# Out:
# [['보스 베이비 2', './basic.naver?code=191597', ['애니메이션', '코미디', '모험'], ['미국'], ['톰 맥그라스'], ['알렉 볼드윈', '에이미 세다리스']], ['극장판 귀멸의 칼날: 무한열차편', './basic.naver?code=196051', ['애니메이션'], ['일본'], ['소토자키 하루오'], ['하나에 나츠키', '키토 아카리']], ['크루엘라', './basic.naver?code=187322', ['드라마', '범죄', '코미디'], ['미국'], ['크레이그 질레스피'], ['엠마 스톤']], ['루카', './basic.naver?code=202903', ['애니메이션', '모험', '코미디'], ['미국'], ['엔리코 카사로사'], ['제이콥 트렘블레이', '잭 딜런 그레이저', '엠마 버만']], ['이보다 더 좋을 순 없다', './basic.naver?code=18878', ['코미디', '드라마'], ['미국'], ['제임스 L. 브룩스'], ['잭 니콜슨', '헬렌 헌트', '그렉 키니어']], ['러브 액츄얼리', './basic.naver?code=36843', ['멜로/로맨스', '드라마', '코미디'], ['영국', '미국'], ['리차드 커티스'], ['휴 그랜트', '리암 니슨', '콜린 퍼스']], ['중경삼림', './basic.naver?code=17059', ['드라마'], ['홍콩'], ['왕가위'], ['임청하', '양조위', '왕페이']], ['너의 이름은.', './basic.naver?code=150198', ['애니메이션', '드라마', '멜로/로맨스'], ['일본'], ['신카이 마코토'], ['카미키 류노스케', '카미시라이시 모네']], ['화양연화', './basic.naver?code=28876', ['드라마', '멜로/로맨스'], ['홍콩', '프랑스'], ['왕가위'], ['장만옥', '양조위']], ['블랙 위도우', './basic.naver?code=184318', ['액션', '모험', 'SF'], ['미국'], ['케이트 쇼트랜드'], ['스칼릿 조핸슨', '플로렌스 퓨', '레이첼 와이즈']], ['노매드랜드', './basic.naver?code=196215', ['드라마'], ['미국'], ['클로이 자오'], ['프란시스 맥도맨드']], ['링', './basic.naver?code=28465', ['공포', '드라마', '스릴러', '미스터리'], ['일본'], ['나카타 히데오'], ['마츠시마 나나코', '나카타니 미키', '사나다 히로유키']], ['이스케이프 룸 2: 노 웨이 아웃', './basic.naver?code=191548', ['액션', '공포', '스릴러'], ['미국'], ['애덤 로비텔'], ['테일러 러셀', '로건 밀러']], ['초속5센티미터', './basic.naver?code=66820', ['애니메이션', '드라마'], ['일본'], ['신카이 마코토'], ['미즈하시 켄지', '하나무라 사토미', '오노우에 아야카']], ['인 더 하이츠', './basic.naver?code=191631', ['뮤지컬'], ['미국'], ['존 추'], ['안소니 라모스', '멜리사 바레사', '코리 호킨스']], ['콰이어트 플레이스 2', './basic.naver?code=189368', ['스릴러'], ['미국'], ['존 크래신스키'], ['에밀리 블런트', '킬리언 머피', '밀리센트 시몬스']], ['언어의 정원', './basic.naver?code=106335', ['애니메이션'], ['일본'], ['신카이 마코토'], ['이리노 미유', '하나자와 카나']], ['인사이드 르윈', './basic.naver?code=89627', ['드라마'], ['미국', '프랑스'], ['조엘 코엔', '에단 코엔'], ['오스카 아이삭', '캐리 멀리건', '저스틴 팀버레이크']], ['너의 췌장을 먹고 싶어', './basic.naver?code=159830', ['드라마'], ['일본'], ['츠키카와 쇼'], ['하마베 미나미', '키타무라 타쿠미']], ['날씨의 아이', './basic.naver?code=181114', ['애니메이션'], ['일본'], ['신카이 마코토'], ['심규혁', '김유림', '최한']], ['내 남자친구의 결혼식', './basic.naver?code=18670', ['멜로/로맨스', '코미디'], ['미국'], ['피 제이 호건'], ['줄리아 로버츠', '더모트 멀로니', '카메론 디아즈']], ['분노의 질주: 더 얼티메이트', './basic.naver?code=189150', ['액션'], ['미국'], ['저스틴 린'], ['빈 디젤', '존 시나', '성 강']], ['킬러의 보디가드 2', './basic.naver?code=204624', ['액션', '코미디', '범죄'], ['미국', '영국'], ['패트릭 휴즈'], ['라이언 레이놀즈', '사무엘 L. 잭슨', '셀마 헤이엑']], ['온다', './basic.naver?code=176738', ['공포'], ['일본'], ['나카시마 테츠야'], ['오카다 준이치', '쿠로키 하루', '고마츠 나나']], ['기기괴괴 성형수', './basic.naver?code=194644', ['공포', '스릴러'], ['한국'], ['조경훈'], ['문남숙', '장민혁', '조현정']], ['발신제한', './basic.naver?code=194205', ['드라마', '스릴러'], ['한국'], ['김창주'], ['조우진', '이재인', '진경']], ['파이프라인', './basic.naver?code=187549', ['범죄'], ['한국'], ['유하'], ['서인국', '이수혁', '음문석']], ['컨저링 3: 악마가 시켰다', './basic.naver?code=190726', ['공포', '미스터리', '스릴러'], ['미국'], ['마이클 차베즈'], ['베라 파미가', '패트릭 윌슨', '줄리안 힐리아드']], ['괴기맨숀', './basic.naver?code=205629', ['공포'], ['한국'], ['조바른'], ['성준', '김홍파', '김보라']], ['랑종', './basic.naver?code=204496', ['공포', '스릴러', '드라마'], ['한국', '태국'], ['반종 피산다나쿤'], ['나릴야 군몽콘켓', '싸와니 우툼마', '씨라니 얀키띠칸']], ['여고괴담 여섯번째 이야기 : 모교', './basic.naver?code=187849', ['미스터리', '공포'], ['한국'], ['이미영'], ['김서형', '김현수', '최리']]]

# %%
import pandas as pd

# %%
pd_data=pd.DataFrame(nmovie, columns=['Title','Code','Genre','Nation','Director','Actor'])
pd_data
# Out:
#                  Title                       Code                 Genre  \
# 0             보스 베이비 2  ./basic.naver?code=191597      [애니메이션, 코미디, 모험]
# 1    극장판 귀멸의 칼날: 무한열차편  ./basic.naver?code=196051               [애니메이션]
# 2                 크루엘라  ./basic.naver?code=187322        [드라마, 범죄, 코미디]
# 3                   루카  ./basic.naver?code=202903      [애니메이션, 모험, 코미디]
# 4        이보다 더 좋을 순 없다   ./basic.naver?code=18878            [코미디, 드라마]
# 5              러브 액츄얼리   ./basic.naver?code=36843    [멜로/로맨스, 드라마, 코미디]
# 6                 중경삼림   ./basic.naver?code=17059                 [드라마]
# 7              너의 이름은.  ./basic.naver?code=150198  [애니메이션, 드라마, 멜로/로맨스]
# 8                 화양연화   ./basic.naver?code=28876         [드라마, 멜로/로맨스]
# 9               블랙 위도우  ./basic.naver?code=184318          [액션, 모험, SF]
# 10               노매드랜드  ./basic.naver?code=196215                 [드라마]
# 11                   링   ./basic.naver?code=28465  [공포, 드라마, 스릴러, 미스터리]
# 12  이스케이프 룸 2: 노 웨이 아웃  ./basic.naver?code=191548         [액션, 공포, 스릴러]
# 13             초속5센티미터   ./basic.naver?code=66820          [애니메이션, 드라마]
# 14             인 더 하이츠  ./basic.naver?code=191631                 [뮤지컬]
# 15         콰이어트 플레이스 2  ./basic.naver?code=189368                 [스릴러]
# 16              언어의 정원  ./basic.naver?code=106335               [애니메이션]
# 17             인사이드 르윈   ./basic.naver?code=89627                 [드라마]
# 18        너의 췌장을 먹고 싶어  ./basic.naver?code=159830                 [드라마]
# 19              날씨의 아이  ./basic.naver?code=181114               [애니메이션]
# 20         내 남자친구의 결혼식   ./basic.naver?code=18670         [멜로/로맨스, 코미디]
# 21     분노의 질주: 더 얼티메이트  ./basic.naver?code=189150                  [액션]
# 22          킬러의 보디가드 2  ./basic.naver?code=204624         [액션, 코미디, 범죄]
# 23                  온다  ./basic.naver?code=176738                  [공포]
# 24            기기괴괴 성형수  ./basic.naver?code=194644             [공포, 스릴러]
# 25                발신제한  ./basic.naver?code=194205            [드라마, 스릴러]
# 26               파이프라인  ./basic.naver?code=187549                  [범죄]
# 27      컨저링 3: 악마가 시켰다  ./basic.naver?code=190726       [공포, 미스터리, 스릴러]
# 28                괴기맨숀  ./basic.naver?code=205629                  [공포]
# 29                  랑종  ./basic.naver?code=204496        [공포, 스릴러, 드라마]
# 30  여고괴담 여섯번째 이야기 : 모교  ./basic.naver?code=187849            [미스터리, 공포]
#
#        Nation        Director                          Actor
# 0        [미국]        [톰 맥그라스]             [알렉 볼드윈, 에이미 세다리스]
# 1        [일본]      [소토자키 하루오]              [하나에 나츠키, 키토 아카리]
# 2        [미국]     [크레이그 질레스피]                        [엠마 스톤]
# 3        [미국]      [엔리코 카사로사]  [제이콥 트렘블레이, 잭 딜런 그레이저, 엠마 버만]
# 4        [미국]    [제임스 L. 브룩스]         [잭 니콜슨, 헬렌 헌트, 그렉 키니어]
# 5    [영국, 미국]       [리차드 커티스]          [휴 그랜트, 리암 니슨, 콜린 퍼스]
# 6        [홍콩]           [왕가위]                [임청하, 양조위, 왕페이]
# 7        [일본]       [신카이 마코토]          [카미키 류노스케, 카미시라이시 모네]
# 8   [홍콩, 프랑스]           [왕가위]                     [장만옥, 양조위]
# 9        [미국]      [케이트 쇼트랜드]     [스칼릿 조핸슨, 플로렌스 퓨, 레이첼 와이즈]
# 10       [미국]        [클로이 자오]                    [프란시스 맥도맨드]
# 11       [일본]       [나카타 히데오]  [마츠시마 나나코, 나카타니 미키, 사나다 히로유키]
# 12       [미국]        [애덤 로비텔]                [테일러 러셀, 로건 밀러]
# 13       [일본]       [신카이 마코토]  [미즈하시 켄지, 하나무라 사토미, 오노우에 아야카]
# 14       [미국]           [존 추]     [안소니 라모스, 멜리사 바레사, 코리 호킨스]
# 15       [미국]       [존 크래신스키]    [에밀리 블런트, 킬리언 머피, 밀리센트 시몬스]
# 16       [일본]       [신카이 마코토]              [이리노 미유, 하나자와 카나]
# 17  [미국, 프랑스]  [조엘 코엔, 에단 코엔]   [오스카 아이삭, 캐리 멀리건, 저스틴 팀버레이크]
# 18       [일본]        [츠키카와 쇼]            [하마베 미나미, 키타무라 타쿠미]
# 19       [일본]       [신카이 마코토]                 [심규혁, 김유림, 최한]
# 20       [미국]       [피 제이 호건]    [줄리아 로버츠, 더모트 멀로니, 카메론 디아즈]
# 21       [미국]         [저스틴 린]              [빈 디젤, 존 시나, 성 강]
# 22   [미국, 영국]        [패트릭 휴즈]  [라이언 레이놀즈, 사무엘 L. 잭슨, 셀마 헤이엑]
# 23       [일본]      [나카시마 테츠야]      [오카다 준이치, 쿠로키 하루, 고마츠 나나]
# 24       [한국]           [조경훈]                [문남숙, 장민혁, 조현정]
# 25       [한국]           [김창주]                 [조우진, 이재인, 진경]
# 26       [한국]            [유하]                [서인국, 이수혁, 음문석]
# 27       [미국]       [마이클 차베즈]     [베라 파미가, 패트릭 윌슨, 줄리안 힐리아드]
# 28       [한국]           [조바른]                 [성준, 김홍파, 김보라]
# 29   [한국, 태국]      [반종 피산다나쿤]  [나릴야 군몽콘켓, 싸와니 우툼마, 씨라니 얀키띠칸]
# 30       [한국]           [이미영]                 [김서형, 김현수, 최리]

# %%
pd_data['Code'] = pd_data['Code'].str[-6:]
pd_data
# Out:
#                  Title    Code                 Genre     Nation  \
# 0             보스 베이비 2  191597      [애니메이션, 코미디, 모험]       [미국]
# 1    극장판 귀멸의 칼날: 무한열차편  196051               [애니메이션]       [일본]
# 2                 크루엘라  187322        [드라마, 범죄, 코미디]       [미국]
# 3                   루카  202903      [애니메이션, 모험, 코미디]       [미국]
# 4        이보다 더 좋을 순 없다  =18878            [코미디, 드라마]       [미국]
# 5              러브 액츄얼리  =36843    [멜로/로맨스, 드라마, 코미디]   [영국, 미국]
# 6                 중경삼림  =17059                 [드라마]       [홍콩]
# 7              너의 이름은.  150198  [애니메이션, 드라마, 멜로/로맨스]       [일본]
# 8                 화양연화  =28876         [드라마, 멜로/로맨스]  [홍콩, 프랑스]
# 9               블랙 위도우  184318          [액션, 모험, SF]       [미국]
# 10               노매드랜드  196215                 [드라마]       [미국]
# 11                   링  =28465  [공포, 드라마, 스릴러, 미스터리]       [일본]
# 12  이스케이프 룸 2: 노 웨이 아웃  191548         [액션, 공포, 스릴러]       [미국]
# 13             초속5센티미터  =66820          [애니메이션, 드라마]       [일본]
# 14             인 더 하이츠  191631                 [뮤지컬]       [미국]
# 15         콰이어트 플레이스 2  189368                 [스릴러]       [미국]
# 16              언어의 정원  106335               [애니메이션]       [일본]
# 17             인사이드 르윈  =89627                 [드라마]  [미국, 프랑스]
# 18        너의 췌장을 먹고 싶어  159830                 [드라마]       [일본]
# 19              날씨의 아이  181114               [애니메이션]       [일본]
# 20         내 남자친구의 결혼식  =18670         [멜로/로맨스, 코미디]       [미국]
# 21     분노의 질주: 더 얼티메이트  189150                  [액션]       [미국]
# 22          킬러의 보디가드 2  204624         [액션, 코미디, 범죄]   [미국, 영국]
# 23                  온다  176738                  [공포]       [일본]
# 24            기기괴괴 성형수  194644             [공포, 스릴러]       [한국]
# 25                발신제한  194205            [드라마, 스릴러]       [한국]
# 26               파이프라인  187549                  [범죄]       [한국]
# 27      컨저링 3: 악마가 시켰다  190726       [공포, 미스터리, 스릴러]       [미국]
# 28                괴기맨숀  205629                  [공포]       [한국]
# 29                  랑종  204496        [공포, 스릴러, 드라마]   [한국, 태국]
# 30  여고괴담 여섯번째 이야기 : 모교  187849            [미스터리, 공포]       [한국]
#
#           Director                          Actor
# 0         [톰 맥그라스]             [알렉 볼드윈, 에이미 세다리스]
# 1       [소토자키 하루오]              [하나에 나츠키, 키토 아카리]
# 2      [크레이그 질레스피]                        [엠마 스톤]
# 3       [엔리코 카사로사]  [제이콥 트렘블레이, 잭 딜런 그레이저, 엠마 버만]
# 4     [제임스 L. 브룩스]         [잭 니콜슨, 헬렌 헌트, 그렉 키니어]
# 5        [리차드 커티스]          [휴 그랜트, 리암 니슨, 콜린 퍼스]
# 6            [왕가위]                [임청하, 양조위, 왕페이]
# 7        [신카이 마코토]          [카미키 류노스케, 카미시라이시 모네]
# 8            [왕가위]                     [장만옥, 양조위]
# 9       [케이트 쇼트랜드]     [스칼릿 조핸슨, 플로렌스 퓨, 레이첼 와이즈]
# 10        [클로이 자오]                    [프란시스 맥도맨드]
# 11       [나카타 히데오]  [마츠시마 나나코, 나카타니 미키, 사나다 히로유키]
# 12        [애덤 로비텔]                [테일러 러셀, 로건 밀러]
# 13       [신카이 마코토]  [미즈하시 켄지, 하나무라 사토미, 오노우에 아야카]
# 14           [존 추]     [안소니 라모스, 멜리사 바레사, 코리 호킨스]
# 15       [존 크래신스키]    [에밀리 블런트, 킬리언 머피, 밀리센트 시몬스]
# 16       [신카이 마코토]              [이리노 미유, 하나자와 카나]
# 17  [조엘 코엔, 에단 코엔]   [오스카 아이삭, 캐리 멀리건, 저스틴 팀버레이크]
# 18        [츠키카와 쇼]            [하마베 미나미, 키타무라 타쿠미]
# 19       [신카이 마코토]                 [심규혁, 김유림, 최한]
# 20       [피 제이 호건]    [줄리아 로버츠, 더모트 멀로니, 카메론 디아즈]
# 21         [저스틴 린]              [빈 디젤, 존 시나, 성 강]
# 22        [패트릭 휴즈]  [라이언 레이놀즈, 사무엘 L. 잭슨, 셀마 헤이엑]
# 23      [나카시마 테츠야]      [오카다 준이치, 쿠로키 하루, 고마츠 나나]
# 24           [조경훈]                [문남숙, 장민혁, 조현정]
# 25           [김창주]                 [조우진, 이재인, 진경]
# 26            [유하]                [서인국, 이수혁, 음문석]
# 27       [마이클 차베즈]     [베라 파미가, 패트릭 윌슨, 줄리안 힐리아드]
# 28           [조바른]                 [성준, 김홍파, 김보라]
# 29      [반종 피산다나쿤]  [나릴야 군몽콘켓, 싸와니 우툼마, 씨라니 얀키띠칸]
# 30           [이미영]                 [김서형, 김현수, 최리]

# %%
pd_data['Code'] = pd_data['Code'].str.replace(pat=r'[^\w]', repl=r'', regex=True)
pd_data
# Out:
#                  Title    Code                 Genre     Nation  \
# 0             보스 베이비 2  191597      [애니메이션, 코미디, 모험]       [미국]
# 1    극장판 귀멸의 칼날: 무한열차편  196051               [애니메이션]       [일본]
# 2                 크루엘라  187322        [드라마, 범죄, 코미디]       [미국]
# 3                   루카  202903      [애니메이션, 모험, 코미디]       [미국]
# 4        이보다 더 좋을 순 없다   18878            [코미디, 드라마]       [미국]
# 5              러브 액츄얼리   36843    [멜로/로맨스, 드라마, 코미디]   [영국, 미국]
# 6                 중경삼림   17059                 [드라마]       [홍콩]
# 7              너의 이름은.  150198  [애니메이션, 드라마, 멜로/로맨스]       [일본]
# 8                 화양연화   28876         [드라마, 멜로/로맨스]  [홍콩, 프랑스]
# 9               블랙 위도우  184318          [액션, 모험, SF]       [미국]
# 10               노매드랜드  196215                 [드라마]       [미국]
# 11                   링   28465  [공포, 드라마, 스릴러, 미스터리]       [일본]
# 12  이스케이프 룸 2: 노 웨이 아웃  191548         [액션, 공포, 스릴러]       [미국]
# 13             초속5센티미터   66820          [애니메이션, 드라마]       [일본]
# 14             인 더 하이츠  191631                 [뮤지컬]       [미국]
# 15         콰이어트 플레이스 2  189368                 [스릴러]       [미국]
# 16              언어의 정원  106335               [애니메이션]       [일본]
# 17             인사이드 르윈   89627                 [드라마]  [미국, 프랑스]
# 18        너의 췌장을 먹고 싶어  159830                 [드라마]       [일본]
# 19              날씨의 아이  181114               [애니메이션]       [일본]
# 20         내 남자친구의 결혼식   18670         [멜로/로맨스, 코미디]       [미국]
# 21     분노의 질주: 더 얼티메이트  189150                  [액션]       [미국]
# 22          킬러의 보디가드 2  204624         [액션, 코미디, 범죄]   [미국, 영국]
# 23                  온다  176738                  [공포]       [일본]
# 24            기기괴괴 성형수  194644             [공포, 스릴러]       [한국]
# 25                발신제한  194205            [드라마, 스릴러]       [한국]
# 26               파이프라인  187549                  [범죄]       [한국]
# 27      컨저링 3: 악마가 시켰다  190726       [공포, 미스터리, 스릴러]       [미국]
# 28                괴기맨숀  205629                  [공포]       [한국]
# 29                  랑종  204496        [공포, 스릴러, 드라마]   [한국, 태국]
# 30  여고괴담 여섯번째 이야기 : 모교  187849            [미스터리, 공포]       [한국]
#
#           Director                          Actor
# 0         [톰 맥그라스]             [알렉 볼드윈, 에이미 세다리스]
# 1       [소토자키 하루오]              [하나에 나츠키, 키토 아카리]
# 2      [크레이그 질레스피]                        [엠마 스톤]
# 3       [엔리코 카사로사]  [제이콥 트렘블레이, 잭 딜런 그레이저, 엠마 버만]
# 4     [제임스 L. 브룩스]         [잭 니콜슨, 헬렌 헌트, 그렉 키니어]
# 5        [리차드 커티스]          [휴 그랜트, 리암 니슨, 콜린 퍼스]
# 6            [왕가위]                [임청하, 양조위, 왕페이]
# 7        [신카이 마코토]          [카미키 류노스케, 카미시라이시 모네]
# 8            [왕가위]                     [장만옥, 양조위]
# 9       [케이트 쇼트랜드]     [스칼릿 조핸슨, 플로렌스 퓨, 레이첼 와이즈]
# 10        [클로이 자오]                    [프란시스 맥도맨드]
# 11       [나카타 히데오]  [마츠시마 나나코, 나카타니 미키, 사나다 히로유키]
# 12        [애덤 로비텔]                [테일러 러셀, 로건 밀러]
# 13       [신카이 마코토]  [미즈하시 켄지, 하나무라 사토미, 오노우에 아야카]
# 14           [존 추]     [안소니 라모스, 멜리사 바레사, 코리 호킨스]
# 15       [존 크래신스키]    [에밀리 블런트, 킬리언 머피, 밀리센트 시몬스]
# 16       [신카이 마코토]              [이리노 미유, 하나자와 카나]
# 17  [조엘 코엔, 에단 코엔]   [오스카 아이삭, 캐리 멀리건, 저스틴 팀버레이크]
# 18        [츠키카와 쇼]            [하마베 미나미, 키타무라 타쿠미]
# 19       [신카이 마코토]                 [심규혁, 김유림, 최한]
# 20       [피 제이 호건]    [줄리아 로버츠, 더모트 멀로니, 카메론 디아즈]
# 21         [저스틴 린]              [빈 디젤, 존 시나, 성 강]
# 22        [패트릭 휴즈]  [라이언 레이놀즈, 사무엘 L. 잭슨, 셀마 헤이엑]
# 23      [나카시마 테츠야]      [오카다 준이치, 쿠로키 하루, 고마츠 나나]
# 24           [조경훈]                [문남숙, 장민혁, 조현정]
# 25           [김창주]                 [조우진, 이재인, 진경]
# 26            [유하]                [서인국, 이수혁, 음문석]
# 27       [마이클 차베즈]     [베라 파미가, 패트릭 윌슨, 줄리안 힐리아드]
# 28           [조바른]                 [성준, 김홍파, 김보라]
# 29      [반종 피산다나쿤]  [나릴야 군몽콘켓, 싸와니 우툼마, 씨라니 얀키띠칸]
# 30           [이미영]                 [김서형, 김현수, 최리]

# %%
pd_data.to_excel('./saves/naver_movie_data_now.xls', index=False)
