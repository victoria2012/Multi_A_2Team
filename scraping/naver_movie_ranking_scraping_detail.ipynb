# %% [markdown]
# 맨 아래 for문을 돌리기 전에 윗부분에서 하나씩 테스트를 해보고 for문을 만들었는데 23라인의 오류메시지에 나온 바와 같이 23라인의 2열에서 오류가 나는 이유를 모르겠습니다. 어디에 문제가 있는 걸까요?

# %%
from selenium import webdriver

# %%
import time

# %%
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('./chromedriver.exe')

# %%
driver.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cnt&tg=0&date=20210716')

# %%
time.sleep(5)

# %%
elem = driver.find_element_by_xpath('//*[@id="old_content"]/table/tbody/tr[2]/td[2]/div/a')
elem.click()

# %%
html = driver.page_source
html
# Out:
# '<html lang="ko"><div style="display: none;"><input title="jindoCheck" type="input" name="jindo1626678085161"></div><head>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta http-equiv="imagetoolbar" content="no">\n<title>랑종 : 네이버 영화</title>\n\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\t\n\t\n\n\n\n<meta property="me2:image" content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg">\n<meta property="me2:post_tag" content="네이버영화 랑종">\n<meta property="me2:category1" content="네이버영화">\n<meta property="me2:category2" content="랑종">\n\n\n\n\t\n\t\n\t\n\t\t<meta property="og:title" content="랑종">\n\t\n\n\n<meta property="og:type" content="article">\n\n<meta property="og:url" content="https://movie.naver.com/movie/bi/mi/basic.naver?code=204496">\n\n\n\t\n\t\t<meta property="og:image" content="https://movie-phinf.pstatic.net/20210630_28/1625030138001Xq38w_JPEG/movie_image.jpg?type=m665_443_2">\n\t\n\t\n\n\n\t\n\t<meta property="og:description" content="태
# ...

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <html lang="ko"><div style="display: none;"><input name="jindo1626678085161" title="jindoCheck" type="input"/></div><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <title>랑종 : 네이버 영화</title>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image"/>
# <meta content="네이버영화 랑종" property="me2:post_tag"/>
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="랑종" property="me2:category2"/>
# <meta content="랑종" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/bi/mi/basic.naver?code=204496" property="og:url"/>
# <meta content="https://movie-phinf.pstatic.net/20210630_28/1625030138001Xq38w_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>
# <meta content="태국 북동부 ‘이산’ 지역 낯선 시골 마을.집 안, 숲, 산, 나무, 논밭까지,이 곳의 사람들은모든 것에 ..." property="og:description"/>
# ...

# %%
datas = soup.select('dl.info_spec')
data = datas[0]

# %%
# data.select_one("span:nth-child(1) > a:nth-child(1)").text

# %%
# data.select_one("span:nth-child(1) > a:nth-child(2)").text

# %%
# data.select_one("span:nth-child(1) > a:nth-child(2)").text

# %%
# data.select_one("span:nth-child(2) > a:nth-child(1)").text

# %%
# data.select_one("span:nth-child(2) > a:nth-child(2)").text

# %%
# data.select_one(" p > span:nth-child(3)").text

# %%
# data.select_one("span:nth-child(4) > a:nth-child(1)").text

# %%
# data.select_one("span:nth-child(4) > a:nth-child(2)").text

# %%
# data.select_one("dd:nth-child(4) > p > a").text

# %%
# data.select_one("dd:nth-child(6) > p > a:nth-child(1)").text

# %%
# data.select_one("dd:nth-child(6) > p > a:nth-child(2)").text

# %%
# data.select_one("dd:nth-child(6) > p > a:nth-child(3)").text

# %%
for n in range(2, 51):
    driver.find_element_by_xpath('//*[@id="old_content"]/table/tbody/tr[%s]/td[2]/div/a' %n).click()
    time.sleep(3)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    datas = soup.select('dl.info_spec')
    data = datas[0]
#     print(data)
    
#     try:
    data.select_one('span:nth-child(1) > a:nth-child(1)').text
    data.select_one('pan:nth-child(1) > a:nth-child(2)").text
    data.select_one('pan:nth-child(1) > a:nth-child(2)").text
    data.select_one('span:nth-child(2) > a:nth-child(1)").text
    data.select_one('span:nth-child(2) > a:nth-child(2)").text
    data.select_one('p > span:nth-child(3)").text
    data.select_one('span:nth-child(4) > a:nth-child(1)").text
    data.select_one('span:nth-child(4) > a:nth-child(2)").text
    data.select_one('dd:nth-child(4) > p > a").text
    data.select_one("dd:nth-child(6) > p > a:nth-child(1)").text
    data.select_one("dd:nth-child(6) > p > a:nth-child(2)").text
    data.select_one("dd:nth-child(6) > p > a:nth-child(3)").text
        
#     except BaseException as ex:
#         print(ex)
        
    print('----------')    
        
    driver.back()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-23-44c51328be73> in <module>
#       1 for n in range(2, 51):
# ----> 2     driver.find_element_by_xpath('//*[@id="old_content"]/table/tbody/tr[%s]/td[2]/div/a' %n).click()
#       3     time.sleep(3)
#       4     html = driver.page_source
#       5     soup = BeautifulSoup(html, 'html.parser')
#
# c:\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# c:\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...
