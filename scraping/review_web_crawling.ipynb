# %%
from bs4 import BeautifulSoup
import requests
uri = 'https://movie.naver.com/movie/point/af/list.naver?&page='
data = [] # or list()

for page in range(1, 1001):
    target = uri+str(page)
#     print(target)
    req  = requests.get(target)
    soup = BeautifulSoup(req.content,'html.parser')
    movies = soup.select('tbody > tr')

    for movie in movies:
        title = movie.select('a.movie')
        score = movie.select('td > div > em')
        author = movie.select('a.author')
        data.append([title[0]['href'], title[0].text.strip(),score[0].text.strip(), author[0].text.strip()])
len(data)
# Out:
# 10000

# %%
print(data)
# Out:
# [['?st=mcode&sword=204624&target=after', '킬러의 보디가드 2', '4', 'yhoc****'], ['?st=mcode&sword=187549&target=after', '파이프라인', '4', 'mirj****'], ['?st=mcode&sword=204496&target=after', '랑종', '1', 'chae****'], ['?st=mcode&sword=204781&target=after', '썰', '3', 'mirj****'], ['?st=mcode&sword=120165&target=after', '해어화', '10', 'lady****'], ['?st=mcode&sword=200896&target=after', '꽃다발 같은 사랑을 했다', '9', 'fprl****'], ['?st=mcode&sword=204496&target=after', '랑종', '2', 'oonj****'], ['?st=mcode&sword=71932&target=after', '친정엄마', '10', 'imgi****'], ['?st=mcode&sword=194205&target=after', '발신제한', '2', 'blas****'], ['?st=mcode&sword=184318&target=after', '블랙 위도우', '10', 'sill****'], ['?st=mcode&sword=35554&target=after', '레인 오브 파이어', '10', 'fjqq****'], ['?st=mcode&sword=204496&target=after', '랑종', '8', 'shs0****'], ['?st=mcode&sword=200896&target=after', '꽃다발 같은 사랑을 했다', '1', 'ekdr****'], ['?st=mcode&sword=129687&target=after', '피닉스', '10', 'mist****'], ['?st=mcode&sword=180381&target=after', '장난스런 키스', '10', 'euns****'], ['?st=mcode&sword=82283&target=after', '실버라이닝 플레이북', '10', 'dsmi****'], ['?st=mcode&sword=178267&target=after', '샤먼 로드', '9', 'mira****'], ['?st=mcode&sword=39879&target=after', '아일랜드', '10', 'song****'], ['?st=mcode&sword=37886&target=after', '클레멘타인', '10', 'melc****'], ['?st=mcode&sword=181411&target=after', '해피 데스데이 2 유', '2', 'sjjo****'], ['?st=mcode&sword=72072&target=after', '라스트 나잇', '8', 'dudm****'], ['?st=mcode&sword=189368&target=after', '콰이어트 플레이스 2', '10', 'ajsu****'], ['?st=mcode&sword=184318&target=after', '블랙 위도우', '10', 'jimi****'], ['?st=mcode&sword=191548&target=after', '이스케이프 룸 2: 노 웨이 아웃', '10', 'loon****'], ['?st=mcode&sword=191597&target=after', '보스 베이비 2', '4', 'prno****'], ['?st=mcode&sword=194205&target=after', '발신제한', '6', 'smal****'], ['?st=mcode&sword=129230&target=after', '바후발리: 더 비기닝', '10', 'hanp****'], ['?st=mcode&sword=102431&target=after', '18 : 우리들의 성장 느와르', '6', 'sept****'], ['?st=mcode&sword=196533&target=after', '퍼펙트 케어', '10', 'muoo****'], ['?st=mcode&sword=191597&target=after', '보스 베이비 2', '10', 'cour****'], ['?st=mcode&sword=204496&target=after', '랑종', '6', 'mghe****'], ['?st=mcode&sword=71932&target=after', '친정엄마', '10', 'cher****'], ['?st=mcode&sword=184318&target=after', '블랙 위도우', '10', 'mh41****'], ['?st=mcode&sword=184318&target=after', '블랙 위도우', '2', 'tcap****'], ['?st=mcode&sword=204643&target=after', '허드 앤 씬', '2', 'tata****'], ['?st=mcode&sword=184318&target=after', '블랙 위도우', '9', 'rain****'], ['?st=mcode&sword=196051&target=after', '극장판 귀멸의 칼날: 무한열차편', '10', '1231****'], ['?st=mcode&sword=10158&target=after', '007 선더볼 작전', '8', 'coco****'], ['?st=mcode&sword=196055&target=after', '어니스트 씨프', '1', 'lsy9****'], ['?st=mcode&sword=189141&target=after', '삼진그룹 영어토익반', '6', 'thdg****'], ['?st=mcode&sword=184318&target=after', '블랙 위도우', '3', 'byeo****'], ['?st=mcode&sword=195691&target=after', '어른들은 몰라요', '1', 'han1****'], ['?st=mcode&sword=112236&target=after', '젊은 엄마', '10', 'clas****'], ['?st=mcode&sword=35360&target=after', '이도공간', '2', 'syyt****'], ['?st=mcode&sword=194205&target=after', '발신제한', '1', 'jihy****'], ['?st=mcode&sword=194205&target=after', '발신제한', '1', 'jaey****'], ['?st=mcode&sword=187637&target=after', '은지: 돌이킬 수 없는 그녀', '6', 'kang****'], ['?st=mcode&sword=184318&target=after', '블랙 위도우', '10', 'djfl****'], ['?st=mcode&sword=204496&target=after', '랑종', '10', 'kyz6****'], ['?st=mcode&sword=167421&target=after', '돌멩이', '8', 'fres****'], ['?st=mcode&sword=192620&target=after', '비와 당신의 이야기', '4', 'jung****'], ['?st=mcode&sword=44913&target=after', '아수라', '10', 'rhsd****'], ['?st=mcode&sword=194205&target=after', '발신제한', '10', 'jkb0****'], ['?st=mcode&sword=205966&target=after', '아이스 로드', '1', 'empt****'], ['?st=mcode&sword=204496&target=after', '랑종', '2', 'ho30****'], ['?st=mcode&sword=158178&target=after', '독전', '1', 'gong****'], ['?st=mcode&sword=184318&target=after', '블랙 위도우', '8', 'ho30****'], ['?st=mcode&sword=186342&target=after', '승리호', '1', 'maca****'], ['?st=mcod ...

# %%
import pandas as pd

# %%
pd_data=pd.DataFrame(data, columns=['Code','Title','Score','Author'])
pd_data['Code'] = pd_data['Code'].str[16:22]
pd_data['Code'] = pd_data['Code'].str.replace(pat=r'[^\w]', repl=r'', regex=True)

# %%
pd_data
# Out:
#         Code        Title Score    Author
# 0     204624   킬러의 보디가드 2     4  yhoc****
# 1     187549        파이프라인     4  mirj****
# 2     204496           랑종     1  chae****
# 3     204781            썰     3  mirj****
# 4     120165          해어화    10  lady****
# ...      ...          ...   ...       ...
# 9995  184318       블랙 위도우    10  lis5****
# 9996  159070     자전차왕 엄복동     1  djad****
# 9997   38619      시실리 2km    10  qltl****
# 9998  184318       블랙 위도우     5  figo****
# 9999  189368  콰이어트 플레이스 2    10  msj5****
#
# [10000 rows x 4 columns]

# %%
pd_data.to_csv('pd_data.csv', index=False, encoding='utf-8-sig')
